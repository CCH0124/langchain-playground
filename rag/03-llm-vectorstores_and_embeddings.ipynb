# %% [markdown]
# ## Embeddings
#
# ![image.png](attachment:image.png)
#
# Embeddings 是將文字轉換成向量（數值陣列），這個向量會保留該文字的語意與內容特徵。語意相近的文字，其向量也會彼此接近。
#
#
#
# My dog Rover likes to chase squirrels.
#
# Fluffy, my cat, refuses to eat from a can.
#
# The Chevy Bolt accelerates to 60 mph in 6.7 seconds.
#
#
# 對應的 Embedding 向量：
#
# ![image-2.png](attachment:image-2.png)
#
# 前兩句都是寵物相關，向量非常接近 → 相似度高
#
# 第三句是汽車相關，向量明顯不同 → 相似度低

# %%
from langchain_community.document_loaders import PyMuPDFLoader
loaders = [
    PyMuPDFLoader("./CKA_Curriculum_v1.32.pdf"),
    PyMuPDFLoader("./CKAD_Curriculum_v1.32.pdf"),
    PyMuPDFLoader("./CKS_Curriculum_v1.32.pdf"),
]

pages = []
for loader in loaders:
    pages.extend(loader.load())

# %%
# split
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1500,
    chunk_overlap = 150
)

# %%
splits = text_splitter.split_documents(pages)
len(splits)
# Out:
# 12

# %% [markdown]
# ## Embeddings

# %%
from langchain_ollama import OllamaEmbeddings
embeddings = OllamaEmbeddings(model="llama3")

# %%
sentence1 = "i like dogs"
sentence2 = "i like lions"
sentence3 = "the weather is hot"

# %%
embedding1 = embeddings.embed_query(sentence1)
embedding2 = embeddings.embed_query(sentence2)
embedding3 = embeddings.embed_query(sentence3)

# %%
import numpy as np
np.dot(embedding1, embedding2) # 最接近
# Out:
# np.float64(0.6562301109688053)

# %%
np.dot(embedding1, embedding3)
# Out:
# np.float64(0.6343237340960042)

# %%
np.dot(embedding2, embedding3)
# Out:
# np.float64(0.4927557062041043)

# %% [markdown]
# ## Vector stores

# %%
# %pip install langchain-chroma
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain-chroma
#   Downloading langchain_chroma-0.2.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: langchain-core>=0.3.60 in /home/itachi/.local/lib/python3.11/site-packages (from langchain-chroma) (0.3.60)
# Requirement already satisfied: chromadb>=1.0.9 in /home/itachi/.local/lib/python3.11/site-packages (from langchain-chroma) (1.0.9)
# Requirement already satisfied: numpy>=1.26.0 in /home/itachi/.local/lib/python3.11/site-packages (from langchain-chroma) (2.2.6)
# Requirement already satisfied: pyyaml>=6.0.0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (6.0.2)
# Requirement already satisfied: build>=1.0.3 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (4.12.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (32.0.1)
# Requirement already satisfied: tqdm>=4.65.0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (4.67.1)
# Requirement already satisfied: typer>=0.9.0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (0.15.4)
# Requirement already satisfied: pydantic>=1.9 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (2.11.4)
# Requirement already satisfied: importlib-resources in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (6.5.2)
# Requirement already satisfied: httpx>=0.27.0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (0.27.2)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.33.1)
# Requirement already satisfied: mmh3>=4.0.1 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (5.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (4.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.33.1)
# Requirement already satisfied: fastapi==0.115.9 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (0.115.9)
# Requirement already satisfied: orjson>=3.9.12 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (3.10.18)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.33.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (0.21.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (7.7.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (9.1.2)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (4.3.0)
# Requirement already satisfied: rich>=10.11.0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (14.0.0)
# Requirement already satisfied: posthog>=2.4.0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (4.0.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (0.54b1)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.22.0)
# Requirement already satisfied: grpcio>=1.58.0 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.71.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (0.34.2)
# Requirement already satisfied: pypika>=0.48.9 in /home/itachi/.local/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (0.48.9)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /home/itachi/.local/lib/python3.11/site-packages (from fastapi==0.115.9->chromadb>=1.0.9->langchain-chroma) (0.45.3)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in /home/itachi/.local/lib/python3.11/site-packages (from langchain-core>=0.3.60->langchain-chroma) (0.3.42)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/itachi/.local/lib/python3.11/site-packages (from langchain-core>=0.3.60->langchain-chroma) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/itachi/.local/lib/python3.11/site-packages (from langchain-core>=0.3.60->langchain-chroma) (24.2)
# Requirement already satisfied: pyproject_hooks in /home/itachi/.local/lib/python3.11/site-packages (from build>=1.0.3->chromadb>=1.0.9->langchain-chroma) (1.2.0)
# Requirement already satisfied: anyio in /home/itachi/.local/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (4.6.2.post1)
# Requirement already satisfied: sniffio in /home/itachi/.local/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (1.3.1)
# Requirement already satisfied: certifi in /home/itachi/.local/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/itachi/.local/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (1.0.7)
# Requirement already satisfied: idna in /home/itachi/.local/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/itachi/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/itachi/.local/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.3.60->langchain-chroma) (3.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/itachi/.local/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (24.2.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/itachi/.local/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (0.21.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/itachi/.local/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/itachi/.local/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (0.35.1)
# Requirement already satisfied: requests-oauthlib in /home/itachi/.local/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/itachi/.local/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/itachi/.local/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /home/itachi/.local/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.10)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/itachi/.local/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (1.8.0)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/itachi/.local/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.40.1)
# Requirement already satisfied: urllib3>=1.24.2 in /home/itachi/.local/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.2.3)
# Requirement already satisfied: requests in /home/itachi/.local/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/itachi/.local/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.126->langchain-core>=0.3.60->langchain-chroma) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/itachi/.local/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.126->langchain-core>=0.3.60->langchain-chroma) (0.23.0)
# Requirement already satisfied: coloredlogs in /home/itachi/.local/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/itachi/.local/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (25.2.10)
# Requirement already satisfied: protobuf in /home/itachi/.local/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (5.29.4)
# Requirement already satisfied: sympy in /home/itachi/.local/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (1.14.0)
# Requirement already satisfied: deprecated>=1.2.6 in /home/itachi/.local/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /home/itachi/.local/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma) (8.6.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/itachi/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.70.0)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in /home/itachi/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in /home/itachi/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in /home/itachi/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.9->langchain-chroma) (0.54b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in /home/itachi/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.9->langchain-chroma) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in /home/itachi/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.9->langchain-chroma) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in /home/itachi/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.9->langchain-chroma) (0.54b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/itachi/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.9->langchain-chroma) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /home/itachi/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.9->langchain-chroma) (3.8.1)
# Requirement already satisfied: distro>=1.5.0 in /usr/lib/python3/dist-packages (from posthog>=2.4.0->chromadb>=1.0.9->langchain-chroma) (1.7.0)
# Requirement already satisfied: backoff>=1.10.0 in /home/itachi/.local/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=1.0.9->langchain-chroma) (2.2.1)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/itachi/.local/lib/python3.11/site-packages (from pydantic>=1.9->chromadb>=1.0.9->langchain-chroma) (2.33.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/itachi/.local/lib/python3.11/site-packages (from pydantic>=1.9->chromadb>=1.0.9->langchain-chroma) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/itachi/.local/lib/python3.11/site-packages (from pydantic>=1.9->chromadb>=1.0.9->langchain-chroma) (0.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/itachi/.local/lib/python3.11/site-packages (from rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/itachi/.local/lib/python3.11/site-packages (from rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/itachi/.local/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (0.31.2)
# Requirement already satisfied: click<8.2,>=8.0.0 in /home/itachi/.local/lib/python3.11/site-packages (from typer>=0.9.0->chromadb>=1.0.9->langchain-chroma) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/itachi/.local/lib/python3.11/site-packages (from typer>=0.9.0->chromadb>=1.0.9->langchain-chroma) (1.5.4)
# Requirement already satisfied: websockets>=10.4 in /home/itachi/.local/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (15.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/itachi/.local/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/itachi/.local/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (1.0.5)
# Requirement already satisfied: python-dotenv>=0.13 in /home/itachi/.local/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (1.1.0)
# Requirement already satisfied: httptools>=0.6.3 in /home/itachi/.local/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (0.6.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/itachi/.local/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.4.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/itachi/.local/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (5.5.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/itachi/.local/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (4.9.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/itachi/.local/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (2025.3.2)
# Requirement already satisfied: filelock in /home/itachi/.local/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (3.18.0)
# Requirement already satisfied: zipp>=3.20 in /home/itachi/.local/lib/python3.11/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /home/itachi/.local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/itachi/.local/lib/python3.11/site-packages (from requests->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (3.4.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/itachi/.local/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/itachi/.local/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/itachi/.local/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.6.1)
# Installing collected packages: langchain-chroma
# Successfully installed langchain-chroma-0.2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_chroma import Chroma

# %%
persist_directory = './chroma/'

# %%
# !rm -rf ./chroma  # remove old database files if any

# %%
vectordb = Chroma.from_documents(
    documents=splits,
    embedding=embeddings,
    persist_directory=persist_directory
)

# %%
print(vectordb._collection.count())
# Out:
# 12

# %%
vectordb.persist()
# Out:
# /tmp/ipykernel_1073/3711397106.py:1: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vectordb.persist()

# %% [markdown]
# ### Similarity Search

# %%
question = "CKS Curriculum"

# %%
docs = vectordb.similarity_search(question, k=3)

# %%
len(docs) # k 為 3，理論應為 3
# Out:
# 3

# %%
docs[0].page_content
# Out:
# 'Certified Kubernetes Security Specialist (CKS) Exam Curriculum\n2\nThis document provides the curriculum outline of the Knowledge, Skills and Abilities \nthat a Certified Kubernetes Security Specialist (CKS) can be expected to demonstrate.\nCKS Curriculum\n15% - Cluster Setup\n20% - Minimize Microservice \nVulnerabilities\n15% - Cluster Hardening\n20% - Supply Chain Security\n•\t Use Network security policies to restrict \ncluster level access\n•\t Use CIS benchmark to review the security \nconfiguration of Kubernetes components \n(etcd, kubelet, kubedns, kubeapi)\n•\t Properly set up Ingress objects with TLS\n•\t Protect node metadata and endpoints\n•\t Verify platform binaries before deploying\n•\t Use appropriate pod security standards\n•\t Manage kubernetes secrets\n•\t Understand and implement isolation\ntechniques (multi-tenancy, sandboxed \ncontainers, etc.)\n•\t Implement Pod-to-Pod encryption\n(Cilium, Istio)\n•\t Use Role Based Access Controls to \nminimize exposure\n•\t Exercise caution in using service accounts \ne.g. disable defaults, minimize permissions \non newly created ones\n•\t Restrict access to Kubernetes API\n•\t Upgrade Kubernetes to avoid vulnerabilities\n•\t Minimize base image footprint\n•\t Understand your supply chain (e.g. SBOM, \nCI/CD, artifact repositories)\n•\t Secure your supply chain (permitted\nregistries, sign and validate artifacts, etc.)\n•\t Perform static analysis of user workloads \nand container images (e.g. Kubesec, \nKubeLinter)\n10% - System Hardening'

# %%
question = "Argo CD in CNCF ?"

# %%
docs = vectordb.similarity_search(question,k=5)

# %%
docs[0]
# Out:
# Document(metadata={'creationDate': "D:20241211195527-05'00'", 'creator': 'Adobe InDesign 20.0 (Macintosh)', 'trapped': '', 'creationdate': '2024-12-11T19:55:27-05:00', 'moddate': '2024-12-11T19:55:27-05:00', 'author': '', 'file_path': './CKA_Curriculum_v1.32.pdf', 'keywords': '', 'producer': 'Adobe PDF Library 17.0', 'format': 'PDF 1.4', 'title': '', 'page': 2, 'total_pages': 3, 'modDate': "D:20241211195527-05'00'", 'subject': '', 'source': './CKA_Curriculum_v1.32.pdf'}, page_content='Cloud native computing uses an open source software stack to \ndeploy applications as microservices, packaging each part into its \nown container, and dynamically orchestrating those containers to \noptimize resource utilization. The Cloud Native Computing Foundation \n(CNCF) hosts critical components of those software stacks including \nKubernetes, Fluentd, Linkerd, Prometheus, OpenTracing and gRPC; \nbrings together the industry’s top developers, end users, and vendors; \nand serves as a neutral home for collaboration. CNCF is part of The \nLinux Foundation, a nonprofit organization. For more information \nabout CNCF, please visit: https://cncf.io/.')

# %%
docs[1]
# Out:
# Document(metadata={'keywords': '', 'producer': '3.0.24 (5.1.10)', 'modDate': "D:20250519175150+02'00'", 'format': 'PDF 1.5', 'page': 2, 'trapped': '', 'creationDate': "D:20250423093125-04'00'", 'creator': 'Adobe InDesign 20.0 (Macintosh)', 'moddate': '2025-05-19T17:51:50+02:00', 'source': './CKAD_Curriculum_v1.32.pdf', 'total_pages': 3, 'author': '', 'creationdate': '2025-04-23T09:31:25-04:00', 'title': '', 'subject': '', 'file_path': './CKAD_Curriculum_v1.32.pdf'}, page_content='Cloud native computing uses an open source software stack to \ndeploy applications as microservices, packaging each part into its \nown container, and dynamically orchestrating those containers to \noptimize resource utilization. The Cloud Native Computing Foundation \n(CNCF) hosts critical components of those software stacks including \nKubernetes, Fluentd, Linkerd, Prometheus, OpenTracing and gRPC; \nbrings together the industry’s top developers, end users, and vendors; \nand serves as a neutral home for collaboration. CNCF is part of The \nLinux Foundation, a nonprofit organization. For more information \nabout CNCF, please visit: https://cncf.io/.')

# %%
question = "CKAD Curriculum topic"

# %%
docs = vectordb.similarity_search(question,k=5)

# %%
for doc in docs:
    print(doc.metadata)
# Out:
# {'source': './CKAD_Curriculum_v1.32.pdf', 'format': 'PDF 1.5', 'moddate': '2025-05-19T17:51:50+02:00', 'subject': '', 'trapped': '', 'modDate': "D:20250519175150+02'00'", 'producer': '3.0.24 (5.1.10)', 'creationDate': "D:20250423093125-04'00'", 'total_pages': 3, 'creationdate': '2025-04-23T09:31:25-04:00', 'title': '', 'file_path': './CKAD_Curriculum_v1.32.pdf', 'keywords': '', 'page': 1, 'creator': 'Adobe InDesign 20.0 (Macintosh)', 'author': ''}
# {'title': '', 'producer': 'Adobe PDF Library 17.0', 'keywords': '', 'creator': 'Adobe InDesign 20.0 (Macintosh)', 'total_pages': 3, 'page': 0, 'creationdate': '2025-04-08T08:47:51-04:00', 'source': './CKS_Curriculum_v1.32.pdf', 'trapped': '', 'file_path': './CKS_Curriculum_v1.32.pdf', 'modDate': "D:20250408084751-04'00'", 'creationDate': "D:20250408084751-04'00'", 'subject': '', 'format': 'PDF 1.4', 'author': '', 'moddate': '2025-04-08T08:47:51-04:00'}
# {'file_path': './CKAD_Curriculum_v1.32.pdf', 'subject': '', 'keywords': '', 'title': '', 'total_pages': 3, 'trapped': '', 'source': './CKAD_Curriculum_v1.32.pdf', 'creationdate': '2025-04-23T09:31:25-04:00', 'author': '', 'modDate': "D:20250519175150+02'00'", 'creator': 'Adobe InDesign 20.0 (Macintosh)', 'format': 'PDF 1.5', 'moddate': '2025-05-19T17:51:50+02:00', 'creationDate': "D:20250423093125-04'00'", 'page': 0, 'producer': '3.0.24 (5.1.10)'}
# {'title': '', 'page': 1, 'creator': 'Adobe InDesign 20.0 (Macintosh)', 'creationDate': "D:20250423093125-04'00'", 'source': './CKAD_Curriculum_v1.32.pdf', 'creationdate': '2025-04-23T09:31:25-04:00', 'trapped': '', 'subject': '', 'author': '', 'total_pages': 3, 'format': 'PDF 1.5', 'file_path': './CKAD_Curriculum_v1.32.pdf', 'modDate': "D:20250519175150+02'00'", 'moddate': '2025-05-19T17:51:50+02:00', 'producer': '3.0.24 (5.1.10)', 'keywords': ''}
# {'creator': 'Adobe InDesign 20.0 (Macintosh)', 'creationdate': '2025-04-08T08:47:51-04:00', 'title': '', 'format': 'PDF 1.4', 'modDate': "D:20250408084751-04'00'", 'producer': 'Adobe PDF Library 17.0', 'source': './CKS_Curriculum_v1.32.pdf', 'file_path': './CKS_Curriculum_v1.32.pdf', 'total_pages': 3, 'keywords': '', 'subject': '', 'trapped': '', 'author': '', 'moddate': '2025-04-08T08:47:51-04:00', 'page': 1, 'creationDate': "D:20250408084751-04'00'"}

# %%
print(docs[1].page_content)
# Out:
# Certified Kubernetes
# Security Specialist (CKS)
# Exam Curriculum
# A Cloud Native Computing Foundation (CNCF) Publication
# cncf.io
